# %%
# !pip install pandas numpy requests

# %%
import pandas as pd
import numpy as np
import requests

# %%
dataset_links = [
    'https://www.kaggle.com/datasets/vijaythurimella/customer-support-tickets',
    'https://www.kaggle.com/code/aniketg11/support-tickets-classification/input',
    'https://github.com/karolzak/support-tickets-classification',
    'https://www.kaggle.com/code/fadlyramdani/bank-customer-complaints-eda-lstm/input?select=complaints.csv'
]

# %%
evaluation_criteria = {
    "Diversity": [True, True, True, False],
    "Size": ["Large", "Medium", "Medium", "Large"],
    "Attributes": [True, True, True, True],
    "Real-world Relevance": [True, True, True, True],
    "Availability": [True, True, True, True]
}

# %%
df_evaluation = pd.DataFrame(evaluation_criteria, index=[
    "Customer Support Tickets (Kaggle)",
    "Support Tickets Classification (Kaggle)",
    "Support Tickets Classification (GitHub)",
    "Bank Customer Complaints (Kaggle)"
])

# %%
print("Dataset Evaluation Summary:")
print(df_evaluation)
# Out:
# Dataset Evaluation Summary:
#                                          Diversity    Size  Attributes  \
# Customer Support Tickets (Kaggle)             True   Large        True
# Support Tickets Classification (Kaggle)       True  Medium        True
# Support Tickets Classification (GitHub)       True  Medium        True
# Bank Customer Complaints (Kaggle)            False   Large        True
#
#                                          Real-world Relevance  Availability
# Customer Support Tickets (Kaggle)                        True          True
# Support Tickets Classification (Kaggle)                  True          True
# Support Tickets Classification (GitHub)                  True          True
# Bank Customer Complaints (Kaggle)                        True          True

# %%
# !wget -O customer_support_dataset.csv "https://www.kaggleusercontent.com/code/fadlyramdani/bank-customer-complaints-eda-lstm/input/complaints.csv"
# Out:
# --2024-12-24 11:15:20--  https://www.kaggleusercontent.com/code/fadlyramdani/bank-customer-complaints-eda-lstm/input/complaints.csv
# Resolving www.kaggleusercontent.com (www.kaggleusercontent.com)... 35.190.26.106
# Connecting to www.kaggleusercontent.com (www.kaggleusercontent.com)|35.190.26.106|:443... connected.
# HTTP request sent, awaiting response... 404 Not Found
# 2024-12-24 11:15:20 ERROR 404: Not Found.

# %%
# Install required libraries
# !pip install pandas numpy matplotlib seaborn requests

# %%
# Install required libraries
# !pip install pandas numpy matplotlib seaborn requests

# %%
# Import necessary libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# Dataset links
dataset_links = [
    'https://www.kaggleusercontent.com/code/fadlyramdani/bank-customer-complaints-eda-lstm/input/complaints.csv'
]

# Download Dataset
# The original URL might be protected and requires a Kaggle API token.
# This code snippet uses the requests library to download the file, which might handle authentication better.
import requests

url = dataset_links[0]
response = requests.get(url)

with open('customer_support_dataset.csv', 'wb') as f:
    f.write(response.content)

# Load dataset
df = pd.read_csv('customer_support_dataset.csv')

# Display the first few rows
df.head()
# Out:
# ...
# Empty DataFrame
# Columns: [response 404 (backend NotFound),  service rules for the path non-existent ]
# Index: []

# %%
# Check for missing values
print("Missing Values:")
print(df.isnull().sum())

# Drop rows with missing values (if necessary)
df = df.dropna()

# Check data types
print("\nData Types:")
print(df.dtypes)

# Basic summary statistics
print("\nSummary Statistics:")
print(df.describe())
# Out:
# Missing Values:
# response 404 (backend NotFound)              0
#  service rules for the path non-existent     0
# dtype: int64
#
# Data Types:
# response 404 (backend NotFound)              object
#  service rules for the path non-existent     object
# dtype: object
#
# Summary Statistics:
#        response 404 (backend NotFound)  \
# count                                0
# unique                               0
# top                                NaN
# freq                               NaN
#
#         service rules for the path non-existent
# count                                          0
# unique                                         0
# top                                          NaN
# freq                                         NaN

# %%
# Install required libraries
# !pip install pandas numpy matplotlib seaborn requests

# %%
# Import necessary libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# Dataset links
dataset_links = [
    'https://www.kaggleusercontent.com/code/fadlyramdani/bank-customer-complaints-eda-lstm/input/complaints.csv'
]

# Download Dataset
# The original URL might be protected and requires a Kaggle API token.
# This code snippet uses the requests library to download the file, which might handle authentication better.
import requests

url = dataset_links[0]
response = requests.get(url)

with open('customer_support_dataset.csv', 'wb') as f:
    f.write(response.content)

# Load dataset
df = pd.read_csv('customer_support_dataset.csv')

# Display the first few rows
df.head()

# Print the column names to check if 'Issue' exists
print("Column Names:", df.columns)

# Check for missing values in 'Issue' column (if it exists)
if 'Issue' in df.columns:
    print("Missing Values in 'Issue' column:")
    print(df['Issue'].isnull().sum())

    # Instead of dropping all rows with any missing values,
    # consider dropping only rows with missing values in the 'Issue' column:
    df = df.dropna(subset=['Issue'])
    # or filling missing values with a placeholder like 'Unknown':
    # df['Issue'] = df['Issue'].fillna('Unknown')
else:
    print("Column 'Issue' not found in the DataFrame.")

# Check data types
print("\nData Types:")
print(df.dtypes)

# Basic summary statistics
print("\nSummary Statistics:")
print(df.describe())

# Plot top 5 most common complaint types
plt.figure
# Out:
# ...
# Column Names: Index(['response 404 (backend NotFound)', ' service rules for the path non-existent '], dtype='object')
# Column 'Issue' not found in the DataFrame.
#
# Data Types:
# response 404 (backend NotFound)              object
#  service rules for the path non-existent     object
# dtype: object
#
# Summary Statistics:
#        response 404 (backend NotFound)  \
# count                                0
# unique                               0
# top                                NaN
# freq                               NaN
#
#         service rules for the path non-existent
# count                                          0
# unique                                         0
# top                                          NaN
# freq                                         NaN
# ...

# %%
# Install required libraries
# !pip install pandas numpy matplotlib seaborn requests

# %%
# Import necessary libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# Dataset links
dataset_links = [
    'https://www.kaggleusercontent.com/code/fadlyramdani/bank-customer-complaints-eda-lstm/input/complaints.csv'
]

# Download Dataset
# The original URL might be protected and requires a Kaggle API token.
# This code snippet uses the requests library to download the file, which might handle authentication better.
import requests

url = dataset_links[0]
response = requests.get(url)

with open('customer_support_dataset.csv', 'wb') as f:
    f.write(response.content)

# Load dataset
df = pd.read_csv('customer_support_dataset.csv')

# Display the first few rows
df.head()

# Print the column names to check if 'Issue' exists
print("Column Names:", df.columns)

# Check if the 'Issue' column exists before accessing it
if 'Issue' in df.columns:
    # Insight 1: Common complaint type
    top_issue = df['Issue'].value_counts().idxmax()
    print(f"Insight 1: The most common issue reported is '{top_issue}'.")
else:
    print("Column 'Issue' not found in the DataFrame. Cannot calculate top issue.")

# Insight 2: Average resolution time
if 'ResolutionTime' in df.columns:
    avg_resolution = df['ResolutionTime'].mean()
    print(f"Insight 2: The average resolution time is {avg_resolution:.2f} hours.")

# Insight 3: Day of the week analysis (if Date column exists)
if 'Date' in df.columns:
    df['Date'] = pd.to_datetime(df['Date'])
    df['DayOfWeek'] = df['Date'].dt.day_name()
    top_day = df['DayOfWeek'].value_counts().idxmax()
    print(f"Insight 3: Most tickets are submitted on '{top_day}'.")
# Out:
# ...
# Column Names: Index(['response 404 (backend NotFound)', ' service rules for the path non-existent '], dtype='object')
# Column 'Issue' not found in the DataFrame. Cannot calculate top issue.

# %%
# Save the cleaned dataset
df.to_csv('cleaned_customer_support_dataset.csv', index=False)

# Download the cleaned dataset
from google.colab import files
files.download('cleaned_customer_support_dataset.csv')

# %%
# Install required libraries
# !pip install pandas numpy matplotlib seaborn requests

# %%
# Import necessary libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# Dataset links
dataset_links = [
    'https://www.kaggleusercontent.com/code/fadlyramdani/bank-customer-complaints-eda-lstm/input/complaints.csv'
]

# Download Dataset
# The original URL might be protected and requires a Kaggle API token.
# This code snippet uses the requests library to download the file, which might handle authentication better.
import requests

url = dataset_links[0]
response = requests.get(url)

with open('customer_support_dataset.csv', 'wb') as f:
    f.write(response.content)

# Load dataset
df = pd.read_csv('customer_support_dataset.csv')

# Display the first few rows
df.head()

# Print the column names to check if 'Issue' exists
print("Column Names:", df.columns)

# Check if the 'Issue' column exists before accessing it
if 'Issue' in df.columns:
    # Insight 1: Most Frequent Issue Type
    top_issue = df['Issue'].value_counts().idxmax()
    top_issue_count = df['Issue'].value_counts().max()
    print(f"Insight 1: The most common issue reported is '{top_issue}' with {top_issue_count} occurrences.")
else:
    print("Column 'Issue' not found in the DataFrame. Cannot calculate top issue.")

# Insight 2: Day of the Week with Most Tickets
# Check if 'Date' column is present and in the correct format
if 'Date' in df.columns and pd.api.types.is_datetime64_any_dtype(df['Date']):
    # Convert 'Date' column to datetime if needed
    df['Date'] = pd.to_datetime(df['Date'])
    top_day = df['Date'].dt.day_name().value_counts().idxmax()
    print(f"Insight 2: The highest number of tickets are raised on '{top_day}'.")
else:
    print("Column 'Date' not found or not in datetime format. Cannot calculate day of the week analysis.")

# Insight 3: Sentiment Analysis (if sentiment column exists)
if 'Sentiment' in df.columns:
    sentiment_counts = df['Sentiment'].value_counts()
    print("Insight 3: Sentiment distribution of tickets:")
    print(sentiment_counts)
else:
    print("Column 'Sentiment' not found in the DataFrame. Cannot perform sentiment analysis.")
# Out:
# ...
# Column Names: Index(['response 404 (backend NotFound)', ' service rules for the path non-existent '], dtype='object')
# Column 'Issue' not found in the DataFrame. Cannot calculate top issue.
# Column 'Date' not found or not in datetime format. Cannot calculate day of the week analysis.
# Column 'Sentiment' not found in the DataFrame. Cannot perform sentiment analysis.

# %%
# Install required libraries
# !pip install pandas numpy matplotlib seaborn requests

# %%
# Import necessary libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# Dataset links
dataset_links = [
    'https://www.kaggleusercontent.com/code/fadlyramdani/bank-customer-complaints-eda-lstm/input/complaints.csv'
]

# Download Dataset
# The original URL might be protected and requires a Kaggle API token.
# This code snippet uses the requests library to download the file, which might handle authentication better.
import requests

url = dataset_links[0]
response = requests.get(url)

with open('customer_support_dataset.csv', 'wb') as f:
    f.write(response.content)

# Load dataset
df = pd.read_csv('customer_support_dataset.csv')

# Display the first few rows
df.head()

# Print the column names to verify if 'Issue' exists
print("Column Names:", df.columns)

# Check if the 'Issue' column exists before accessing it
if 'Issue' in df.columns:
    # Identify issues that repeat and are simple
    top_easy_issues = df['Issue'].value_counts().head(5)
    print("Top Issues Solvable by Automated Responses:")
    print(top_easy_issues)
else:
    print("Column 'Issue' not found in the DataFrame. Cannot identify top issues.")
# Out:
# ...
# Column Names: Index(['response 404 (backend NotFound)', ' service rules for the path non-existent '], dtype='object')
# Column 'Issue' not found in the DataFrame. Cannot identify top issues.

# %%
# Install required libraries
# !pip install pandas numpy matplotlib seaborn requests

# %%
# Import necessary libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# Dataset links
dataset_links = [
    'https://www.kaggleusercontent.com/code/fadlyramdani/bank-customer-complaints-eda-lstm/input/complaints.csv'
]

# Download Dataset
# The original URL might be protected and requires a Kaggle API token.
# This code snippet uses the requests library to download the file, which might handle authentication better.
import requests

url = dataset_links[0]
response = requests.get(url)

with open('customer_support_dataset.csv', 'wb') as f:
    f.write(response.content)

# Load dataset
df = pd.read_csv('customer_support_dataset.csv')

# Display the first few rows
df.head()

# Print the column names to verify if 'Issue' exists
print("Column Names:", df.columns)

# Check if the 'Issue' column exists before accessing it
if 'Issue' in df.columns:
    # Identify issues that repeat and are simple
    top_easy_issues = df['Issue'].value_counts().head(5)
    print("Top Issues Solvable by Automated Responses:")
    print(top_easy_issues)

    # Save insights into a text file
    # The code to save insights was incorrectly indented inside the 'else' block.
    # It should be outside the 'if/else' block to execute regardless of whether 'Issue' column exists.
    insights = f"""
    1. Most common issue: {top_issue} ({top_issue_count} occurrences)
    2. Most tickets are raised on: {top_day}
    3. Top easy-to-solve issues:
    {top_easy_issues.to_string()}
    """
    with open("insights_summary.txt", "w") as f:
        f.write(insights)

    # Download the insights file
    from google.colab import files  # Import files here if needed
    files.download('insights_summary.txt')

else:
    print("Column 'Issue' not found in the DataFrame. Cannot identify top issues.")
# Out:
# ...
# Column Names: Index(['response 404 (backend NotFound)', ' service rules for the path non-existent '], dtype='object')
# Column 'Issue' not found in the DataFrame. Cannot identify top issues.

# %%
# Clone GitHub repository
# !git init
# !git config --global user.email "your_email@example.com"
# !git config --global user.name "your_username"
# !git remote add origin https://github.com/your-username/Customer-Support-Tickets-Analysis.git
# Out:
# hint: Using 'master' as the name for the initial branch. This default branch name
# hint: is subject to change. To configure the initial branch name to use in all
# hint: of your new repositories, which will suppress this warning, call:
# hint:
# hint: 	git config --global init.defaultBranch <name>
# hint:
# hint: Names commonly chosen instead of 'master' are 'main', 'trunk' and
# hint: 'development'. The just-created branch can be renamed via this command:
# hint:
# hint: 	git branch -m <name>
# Initialized empty Git repository in /content/.git/

# %%
import os

folders = [
    "Analysis",
    "Sentiment_Analysis",
    "Real_Time_Escalation",
    "Automated_Response",
    "Integrations",
    "Issue_Prevention_Dashboard"
]

for folder in folders:
    os.makedirs(folder, exist_ok=True)

# Define 'insights' variable here before using it
if 'Issue' in df.columns:
    top_issue = df['Issue'].value_counts().idxmax()
    top_issue_count = df['Issue'].value_counts().max()
    top_easy_issues = df['Issue'].value_counts().head(5)  # Assuming this is how you define top_easy_issues

    if 'Date' in df.columns and pd.api.types.is_datetime64_any_dtype(df['Date']):
        df['Date'] = pd.to_datetime(df['Date'])
        top_day = df['Date'].dt.day_name().value_counts().idxmax()
    else:
        top_day = "N/A (Date column not found or not in datetime format)"  # Provide a default value

    insights = f"""
    1. Most common issue: {top_issue} ({top_issue_count} occurrences)
    2. Most tickets are raised on: {top_day}
    3. Top easy-to-solve issues:
    {top_easy_issues.to_string()}
    """
else:
    insights = "Column 'Issue' not found in the DataFrame. Cannot generate insights." # Provide a default value

# Save analysis results in folders
df.to_csv('Analysis/cleaned_dataset.csv', index=False)
with open('Analysis/insights_summary.txt', 'w') as f:
    f.write(insights)
